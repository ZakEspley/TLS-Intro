# %% [markdown]
# # Imports and Setup

# %%
import matplotlib.pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from IPython.display import Image
from qutip import (Qobj, about, basis, Bloch, Bloch3d, coherent, coherent_dm, create, destroy,
                   expect, fock, fock_dm, mesolve, qeye, sigmax, sigmay,
                   sigmaz, sigmam, sigmap, tensor, thermal_dm, sesolve, spre, spost, sprepost, to_super)
from qutip.qip.operations import hadamard_transform as HD, rx, ry, rz
from qutip.ipynbtools import plot_animation
from scipy.optimize import curve_fit
# %matplotlib widget
plt.rc('font', size=16)         # Set the default text font size
plt.rc('axes', titlesize=16)    # Set the axes title font size
plt.rc('axes', labelsize=16)    # Set the axes labels font size
plt.rc('xtick', labelsize=16)   # Set the font size for x tick labels
plt.rc('ytick', labelsize=16)   # Set the font size for y tick labels
plt.rc('legend', fontsize=18)   # Set the legend font size
plt.rc('figure', titlesize=20)  # Set the font size of the figure title
plt.rc('lines', linewidth=3)    # Set the default linewidth
plt.rc("text", usetex=False)

#Adjusting the way to write some of the functions because I'm lazy
σx = sigmax
σy = sigmay
σz = sigmaz
I = qeye

# %% [markdown]
# # Hamiltonian
# We will be using the Hamiltonian for a two level system in an electric field. Generically we write this as:
# $$
# \mathcal{H} = -(\epsilon + 2\vec{p}\cdot \vec{E}(t)\cos(t\phi) )\hat{S}^Z - 2\vec{p}\cdot \vec{E}(t)\sin (2\phi) \hat{S}^X
# $$
# Where we have $\epsilon = \sqrt{\Delta^2+\Delta_T^2}$ where $Delta$ is the energy asymmetry of the double well and $\Delta_T$ is the tunnelling probability between the two wells. $\phi$ defines the ratio between the all the energies in that $\tan 2\phi = \Delta_T/\Delta$, $\sin 2\phi = \Delta_T/\epsilon$, and $\cos 2\phi = \Delta/\epsilon$.
#
# We will consider the case where we have two independent oscillating electric fields. This means that $\vec{E}(t)$ is given by $\vec{E}(t) = \vec{E}_1 \cos(\nu_1 t) + \vec{E}_2 \cos (\nu_2 t)$. This means that the full Hamiltonian is given by
# $$
# \mathcal{H}_2 = -\epsilon \hat{S}^Z - \sum_{i=1,2} 2\hbar \Omega_{Z,i}\cos(\nu_i t) \hat{S}^Z + 2\hbar \Omega_{X,,i}\cos(\nu_i t)\hat{S}^X
# $$
# where $\Omega_{z,i} = \Omega_0\cos(\theta_i)\cos(2\phi)$, $\Omega_{x.i}=\Omega\cos(\theta_i)\sin(2\phi)$ and $\Omega_0$ is the bare Rabi Frequency. $\theta_i$ is the angle between the electric dipole and the $\vec{E}_i$ field for each of teh two fields. We will consider the case that the $\Omega_{Z/X,1}=\Omega_{Z/X,2}\equiv \Omega_X$ so that we can rewrite the X component of the field to be:
# $$
# \Omega_{X,1}\cos(\nu_1 t) + \Omega_{X,2}\cos(\nu_2 t) = \Omega_x(\cos(\nu_1 t)+\cos(\nu_2 t)) = 2\Omega_x \cos(\tilde{\nu} t)\cos(\delta\nu t) \equiv \Omega_x(t)
# $$
# Where we defined $\tilde{\nu}=(\nu_1+\nu_2)/2$ and $\tilde{\nu_2} = (\nu_1-\nu_2)/2$. Then we can ignore the AC Stark term (the $\Omega_{Z,i}$ terms) and we apply the Rotating Wave Approximation we get the final Hamiltonian that we will use:
#
# $$ \mathcal{H}'_2 = -(\epsilon - \hbar\tilde{\nu})\hat{S}^Z -2\hbar\Omega_X\cos(\delta\nu t)\hat{S}^X$$

# %% [markdown]
# ## Define Hamiltonian

# %%
def H2(t: float, args: dict):

    ϵ = args["eps"]
    νp = args["vp"]
    Ωx = args["omegaX"]
    δν = args["dv"]
    return -(ϵ-νp)*Sz - 2*Ωx*np.cos(δν*t)*Sx

# %% [markdown]
# ## Constants

# %%
δν = 0.023
νp = 5.0
Ωx = 0.0633
ϵ = 5.0
Sx = σx()/2
Sy = σy()/2
Sz = σz()/2

# %% [markdown]
# ## First Attempt Just Using the SE Solver

# %%
ψ0 = basis(2,0)
times = np.linspace(0,250,2500)
result = sesolve(H2,ψ0, times, e_ops=[], args=dict(eps=ϵ, vp=νp, omegaX=Ωx, dv=δν), progress_bar=True)
# Out:
# 10.0%. Run time:   1.24s. Est. time left: 00:00:00:11
# 20.0%. Run time:   2.24s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.19s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.10s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.10s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.11s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.16s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.28s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.23s. Est. time left: 00:00:00:01
# Total run time:  10.21s

# %%
fig, ax = plt.subplots(figsize=(16,9))
# probs = np.abs(result.states) ** 2
probs = []
for state in result.states:
    probs.append((np.abs(state[0])**2)[0][0])
# ax.plot(result.times, probs[:,0], label="0")
# ax.plot(result.times, probs[:,1], label="1")
# ax.plot(result.times, probs[:,1]+probs[:,0], label="Sum")
ax.plot(result.times, probs, label="0")
ax.set_xlabel("Time [ns]")
ax.set_ylabel("Probability")
ax.legend()
plt.show()

# %%
(np.abs(result.states[0][0])**2)[0][0]
# Out:
# 1.0

# %%
def sineSqFit(t,A,v,ϕ, DC):
    return A*(np.sin(v*t+ϕ))**2+DC

# %%
pop, pcov = curve_fit(sineSqFit, result.times, probs[:,1].flatten(), [1, 0.1, 0, 0 ])
print(pop)
print("Hello World")
# Out:
# [ 0.15773897  0.10158958 -0.71161677  0.41965077]
# Hello World

# %%
fig, ax = plt.subplots(figsize=(16,9))
probs = np.abs(result.states) ** 2
# ax.plot(result.times, probs[:,0], label="0")
ax.plot(result.times, probs[:,1].flatten(), label="1")
ax.plot(result.times, probs[:,1]+probs[:,0], label="Sum")
ax.plot(result.times, sineSqFit(result.times, *pop))
# ax.plot(result.times, sineSqFit(result.times, *[1, 0.1, 0, 0 ]))
ax.set_xlabel("Time")
ax.set_ylabel("Probability")
ax.legend()
plt.show()

# %%
print(pop)

# %%
def plot_setup(result):

    fig = plt.figure(figsize=(8, 8))
    axes = Axes3D(fig, azim=-40, elev=30)

    return fig, axes

# %%
sphere = None


def plot_result(result, n, fig=None, axes=None):

    global sphere

    if fig is None or axes is None:
        fig, axes = plot_setup(result)

    if not sphere:
        sphere = Bloch(axes=axes)
        sphere.vector_color = ["r"]

    sphere.clear()
    sphere.add_vectors([result.expect[0][n]])
                        # result.expect[1][n],
                        # result.expect[2][n]])
    sphere.add_points(
        [
            result.expect[0][: n + 1],
            # result.expect[1][: n + 1],
            # result.expect[2][: n + 1],
        ],
        meth="l",
    )
    sphere.make_sphere()

    return axes.artists

# %%
plot_animation(plot_setup, plot_result, result, writer="ffmpeg", codec=None)

# %% [markdown]
# ## Trying Bloch Sphere Visualization

# %%
b = Bloch()
b.add_states(result.states[0])
b.add_states(result.states[4])
print(b.fig)
print(b.axes)
b.render()
# Out:
# None
# None

# %%
sphere = Bloch()
sphere.render()
print(sphere.axes, sphere.fig)

def animate(i):
    sphere.clear()
    sphere.add_states(result.states[i])
    sphere.render()
    return sphere.axes

def init():
    sphere.vector_color = ["r"]
    return sphere.axes

# sphere.clear()
# sphere.add_states(result.states[0])
# sphere.render()
ani = animation.FuncAnimation(sphere.fig, animate, len(result.times), init_func=init, blit=False, repeat=False)
writer = animation.PillowWriter(fps=30, bitrate=1800)
ani.save('bloch_sphere3.gif', writer=writer)
# Out:
# Axes3D(0,0;1x1) Figure(500x500)

# %%
dir(b)

# %%
b.render()

# %% [markdown]
# # $T_1$ Simulation

# %%
H = Qobj([[-1,0],[0,1]])
g = 0.01
c_ops = [np.sqrt(g)*sigmam()]
psi0 = basis(2,0)
maxTime = 800
times = np.linspace(0,maxTime, 2*maxTime)
Mresults = mesolve(H, psi0, times, c_ops, progress_bar=True)
# Out:
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 30.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 40.0%. Run time:   0.02s. Est. time left: 00:00:00:00
# 50.0%. Run time:   0.02s. Est. time left: 00:00:00:00
# 60.0%. Run time:   0.03s. Est. time left: 00:00:00:00
# 70.0%. Run time:   0.03s. Est. time left: 00:00:00:00
# 80.0%. Run time:   0.04s. Est. time left: 00:00:00:00
# 90.0%. Run time:   0.04s. Est. time left: 00:00:00:00
# Total run time:   0.05s

# %%
def expFit(t, A, d,DC):
    return A*np.exp(d*t)+DC

# %%
fig, ax = plt.subplots(figsize=(16,9))
# probs = np.abs(Mresults.states) ** 2
# m = Qobj([[0,0],[0,1]])*Mresults.states
# probs=[]
# for state in m:
#     probs.append(state[0,0]+state[1,1])
# ax.plot(result.times, probs[:,0], label="0")
states = np.array(Mresults.states)
ax.plot(Mresults.times, states[:,0,0], label="|0>")
ax.plot(Mresults.times, states[:,1,1], label="|1>")
pop, pcov = curve_fit(expFit, Mresults.times, states[:,1,1], [1,-0.01,0.25])
# ax.plot(Mresults.times, probs, label="1", linewidth=4)
# ax.plot(Mresults.times, expFit(Mresults.times, *pop), "--", label=f"{pop[0]:0.0f}exp({pop[1]:0.2f} t)+{pop[2]:0.1f}", linewidth=3)
# ax.plot(Mresults.times, expFit(Mresults.times, *[1,-0.01,0.25]), "--")
# ax.plot(result.times, probs[:,1]+probs[:,0], label="Sum")

ax.set_xlabel("Time [μs]")
ax.set_ylabel("Probability")
ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data = np.array(Mresults.states)

# %%
data[:,0,0]
# Out:
# array([1.00000000e+00+0.j, 9.95009368e-01+0.j, 9.90043642e-01+0.j, ...,
#        3.38847747e-04+0.j, 3.37156700e-04+0.j, 3.35474095e-04+0.j])

# %%
sphere = Bloch();
sphere.render();
print(sphere.axes, sphere.fig)

def animate(i):
    sphere.clear()
    sphere.add_states(Mresults.states[i])
    sphere.render()
    return sphere.axes

def init():
    sphere.vector_color = ["r"]
    return sphere.axes

# sphere.clear()
# sphere.add_states(result.states[0])
# sphere.render()
ani = animation.FuncAnimation(sphere.fig, animate, len(Mresults.times), init_func=init, blit=False, repeat=False);
writer = animation.PillowWriter(fps=30, bitrate=1800);
ani.save('T1_BlochSphere.gif', writer=writer);
# Out:
# Axes3D(0,0;1x1) Figure(500x500)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\Anaconda3\envs\TLS\Lib\site-packages\matplotlib\animation.py:233, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     232 try:
# --> 233     yield self
#     234 finally:
#
# File ~\Anaconda3\envs\TLS\Lib\site-packages\matplotlib\animation.py:1103, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1101 for anim, d in zip(all_anim, data):
#    1102     # TODO: See if turning off blit is really necessary
# -> 1103     anim._draw_next_frame(d, blit=False)
#    1104     if progress_callback is not None:
#
# File ~\Anaconda3\envs\TLS\Lib\site-packages\matplotlib\animation.py:1138, in Animation._draw_next_frame(self, framedata, blit)
#    1137 self._pre_draw(framedata, blit)
# -> 1138 self._draw_frame(framedata)
#    1139 self._post_draw(framedata, blit)
#
# File ~\Anaconda3\envs\TLS\Lib\site-packages\matplotlib\animation.py:1767, in FuncAnimation._draw_frame(self, framedata)
#    1765 # Call the func with framedata and args. If blitting is desired,
#    1766 # func needs to return a sequence of any artists that were modified.
# -> 1767 self._drawn_artists = self._func(framedata, *self._args)
#    1769 if self._blit:
#
# Cell In[33], line 8, in animate(i)
#       7 sphere.add_states(Mresults.states[i])
# ----> 8 sphere.render()
#       9 return sphere.axes
#
# File ~\Anaconda3\envs\TLS\Lib\site-packages\qutip\bloch.py:639, in Bloch.render(self)
#     638 # Trigger an update of the Bloch sphere if it is already shown:
# --> 639 self.fig.canvas.draw()
#
# File ~\Anaconda3\envs\TLS\Lib\site-packages\matplotlib\backends\backend_webagg_core.py:193, in FigureCanvasWebAggCore.draw(self)
#     192 finally:
# --> 193     self.manager.refresh_all()
#
# AttributeError: 'NoneType' object has no attribute 'refresh_all'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 20
#      18 ani = animation.FuncAnimation(sphere.fig, animate, len(Mresults.times), init_func=init, blit=False, repeat=False);
#      19 writer = animation.PillowWriter(fps=30, bitrate=1800);
# ---> 20 ani.save('T1_BlochSphere.gif', writer=writer);
#
# File ~\Anaconda3\envs\TLS\Lib\site-packages\matplotlib\animation.py:1085, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1081 savefig_kwargs['transparent'] = False   # just to be safe!
#    1082 # canvas._is_saving = True makes the draw_event animation-starting
#    1083 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1084 # widget (both are likewise done in savefig()).
# -> 1085 with mpl.rc_context({'savefig.bbox': None}), \
#    1086      writer.saving(self._fig, filename, dpi), \
#    1087      cbook._setattr_cm(self._fig.canvas,
#    1088                        _is_saving=True, manager=None):
#    1089     for anim in all_anim:
#    1090         anim._init_draw()  # Clear the initial frame
#
# File ~\Anaconda3\envs\TLS\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     153     value = typ()
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#     160     return exc is not value
#
# File ~\Anaconda3\envs\TLS\Lib\site-packages\matplotlib\animation.py:235, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     233     yield self
#     234 finally:
# --> 235     self.finish()
#
# File ~\Anaconda3\envs\TLS\Lib\site-packages\matplotlib\animation.py:501, in PillowWriter.finish(self)
#     500 def finish(self):
# --> 501     self._frames[0].save(
#     502         self.outfile, save_all=True, append_images=self._frames[1:],
#     503         duration=int(1000 / self.fps), loop=0)
#
# IndexError: list index out of range
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## $T_2$ Dephasing Time

# %%
H = Qobj([[0,0],[0,1]])
g = 0.1
c_ops = [np.sqrt(g)*sigmax()]
psi0 = HD()*basis(2,0)
maxTime = 100
times = np.linspace(0,maxTime, 4*maxTime)
Mresults = mesolve(H, psi0, times, c_ops, progress_bar=True)
# Out:
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 30.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 40.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 50.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 60.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 70.0%. Run time:   0.02s. Est. time left: 00:00:00:00
# 80.0%. Run time:   0.02s. Est. time left: 00:00:00:00
# 90.0%. Run time:   0.02s. Est. time left: 00:00:00:00
# Total run time:   0.02s

# %%
Mresults
# Out:
# Result object with mesolve data.
# --------------------------------
# states = True
# num_collapse = 1

# %%
def dampedSineFit(t, A, d, v, ϕ, DC):
    return A*np.exp((d*t))*np.sin(v*t+ ϕ) + DC

# %%
fig, ax = plt.subplots(figsize=(16,9))
# probs = np.abs(Mresults.states) ** 2
tempStates = []
RY = ry(np.pi/2)
for state in Mresults.states:
    tempStates.append(RY*state*RY.dag())
m = Qobj([[0,0],[0,1]])*tempStates
probs=[]
for state in m:
    probs.append((state[0,0]+state[1,1]))
# ax.plot(result.times, probs[:,0], label="0")
pop, pcov = curve_fit(dampedSineFit, Mresults.times, probs, [0.5,-0.1,10/20, 0, 0.5])
ax.plot(Mresults.times, probs, label="1", linewidth=4)
ax.plot(Mresults.times, dampedSineFit(Mresults.times, *pop), "--", label=f"{pop[0]:0.0f}exp({pop[1]:0.2f} t)*sin({pop[2]:0.2f} t+{pop[3]:0.1f})+{pop[4]:0.1f}", linewidth=3)
# ax.plot(Mresults.times, expFit(Mresults.times, *[1,-0.01,0.25]), "--")
# ax.plot(result.times, probs[:,1]+probs[:,0], label="Sum")

ax.set_xlabel("Time [μs]")
ax.set_ylabel("Probability")
ax.legend()
plt.show()

# %%
print(pop)
# Out:
# [-0.27387286 -0.03546636  0.50257809 -0.13095287  0.53864819]

# %%
sphere = Bloch()
sphere.render()
print(sphere.axes, sphere.fig)

def animate(i):
    sphere.clear()
    sphere.add_states(Mresults.states[i])
    sphere.render()
    return sphere.axes

def init():
    sphere.vector_color = ["r"]
    return sphere.axes

# sphere.clear()
# sphere.add_states(result.states[0])
# sphere.render()
ani = animation.FuncAnimation(sphere.fig, animate, len(Mresults.times), init_func=init, blit=False, repeat=False)
writer = animation.PillowWriter(fps=30, bitrate=1800)
ani.save('T1_BlochSphere.gif', writer=writer)
# Out:
# Axes3D(0,0;1x1) Figure(500x500)

# %% [markdown]
# # Recreating Hurst Plots part 2

# %%
δν = 0.025
νp = 5.0
Ωx = 0.0633
ϵ = 5.0
Sx = σx()/2
Sy = σy()/2
Sz = σz()/2
ψ0 = basis(2, 0)
times = np.linspace(0, 250, 2500)
result = sesolve(H2, ψ0, times, e_ops=[], args=dict(eps=ϵ, vp=νp, omegaX=Ωx, dv=δν), progress_bar=True)
# Out:
# 10.0%. Run time:   1.25s. Est. time left: 00:00:00:11
# 20.0%. Run time:   2.25s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.11s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.10s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.35s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.39s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.37s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.25s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.22s. Est. time left: 00:00:00:01
# Total run time:  10.31s

# %%
fig, ax = plt.subplots(figsize=(16,9))
probs = np.abs(result.states) ** 2
# probs = []
# for state in result.states:
#     probs.append((np.abs(state[0])**2)[0][0])
# ax.plot(result.times, probs[:,0], label="0")
ax.plot(result.times, probs[:,1,0], label="1")
# ax.plot(result.times, probs[:,1]+probs[:,0], label="Sum")
# ax.plot(result.times, probs, label="0")
ax.set_xlabel("Time [ns]")
ax.set_ylabel("Probability")
ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
δvmin = 0.010
δvmax = 0.040
nδv = 25
νp = 5.0
Ωx = 0.0633
ϵ = 5.0
Sx = σx()/2
Sy = σy()/2
Sz = σz()/2
ψ0 = basis(2, 0)
times = np.linspace(0, 250, 2500)
results = []
δvs = np.linspace(δvmin,δvmax, nδv)
for δv in δvs:
    result = sesolve(H2, ψ0, times, e_ops=[], args=dict(eps=ϵ, vp=νp, omegaX=Ωx, dv=δv), progress_bar=True)
    results.append(result)
# Out:
# 10.0%. Run time:   1.18s. Est. time left: 00:00:00:10
# 20.0%. Run time:   2.22s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.24s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.20s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.05s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.01s. Est. time left: 00:00:00:04
# 70.0%. Run time:   6.97s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.89s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.83s. Est. time left: 00:00:00:00
# Total run time:   9.83s
# 10.0%. Run time:   1.02s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.05s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.06s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.03s. Est. time left: 00:00:00:06
# 50.0%. Run time:   4.91s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.78s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.65s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.62s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.59s. Est. time left: 00:00:00:00
# Total run time:   9.63s
# 10.0%. Run time:   1.02s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.05s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.03s. Est. time left: 00:00:00:07
# 40.0%. Run time:   3.96s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.89s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.81s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.74s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.72s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.74s. Est. time left: 00:00:00:00
# Total run time:   9.77s
# 10.0%. Run time:   1.03s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.04s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.03s. Est. time left: 00:00:00:07
# 40.0%. Run time:   3.94s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.89s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.80s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.75s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.77s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.78s. Est. time left: 00:00:00:00
# Total run time:   9.81s
# 10.0%. Run time:   1.02s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.05s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.03s. Est. time left: 00:00:00:07
# 40.0%. Run time:   3.89s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.75s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.67s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.66s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.68s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.69s. Est. time left: 00:00:00:00
# Total run time:   9.69s
# 10.0%. Run time:   1.00s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.02s. Est. time left: 00:00:00:08
# 30.0%. Run time:   2.99s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.85s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.75s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.73s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.75s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.75s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.76s. Est. time left: 00:00:00:00
# Total run time:   9.73s
# 10.0%. Run time:   1.01s. Est. time left: 00:00:00:09
# 20.0%. Run time:   1.99s. Est. time left: 00:00:00:07
# 30.0%. Run time:   2.99s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.89s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.89s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.85s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.88s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.88s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.91s. Est. time left: 00:00:00:00
# Total run time:   9.89s
# 10.0%. Run time:   1.04s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.02s. Est. time left: 00:00:00:08
# 30.0%. Run time:   2.99s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.94s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.91s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.95s. Est. time left: 00:00:00:03
# 70.0%. Run time:   7.02s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.06s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.12s. Est. time left: 00:00:00:01
# Total run time:  10.09s
# 10.0%. Run time:   1.06s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.04s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.03s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.06s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.05s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.08s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.16s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.19s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.12s. Est. time left: 00:00:00:01
# Total run time:  10.15s
# 10.0%. Run time:   1.01s. Est. time left: 00:00:00:09
# 20.0%. Run time:   1.99s. Est. time left: 00:00:00:07
# 30.0%. Run time:   2.97s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.92s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.91s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.92s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.96s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.90s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.86s. Est. time left: 00:00:00:00
# Total run time:   9.79s
# 10.0%. Run time:   1.04s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.01s. Est. time left: 00:00:00:08
# 30.0%. Run time:   2.95s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.88s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.89s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.90s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.94s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.86s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.83s. Est. time left: 00:00:00:00
# Total run time:   9.76s
# 10.0%. Run time:   1.01s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.00s. Est. time left: 00:00:00:07
# 30.0%. Run time:   2.94s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.88s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.89s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.91s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.92s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.83s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.75s. Est. time left: 00:00:00:00
# Total run time:   9.85s
# 10.0%. Run time:   1.04s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.03s. Est. time left: 00:00:00:08
# 30.0%. Run time:   2.90s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.89s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.93s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.94s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.93s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.80s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.79s. Est. time left: 00:00:00:00
# Total run time:   9.82s
# 10.0%. Run time:   1.03s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.03s. Est. time left: 00:00:00:08
# 30.0%. Run time:   2.89s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.90s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.91s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.92s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.87s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.76s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.78s. Est. time left: 00:00:00:00
# Total run time:   9.76s
# 10.0%. Run time:   1.00s. Est. time left: 00:00:00:08
# 20.0%. Run time:   2.01s. Est. time left: 00:00:00:08
# 30.0%. Run time:   2.92s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.95s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.98s. Est. time left: 00:00:00:04
# 60.0%. Run time:   6.00s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.94s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.94s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.97s. Est. time left: 00:00:00:00
# Total run time:   9.99s
# 10.0%. Run time:   1.01s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.05s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.05s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.08s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.07s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.09s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.09s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.10s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.10s. Est. time left: 00:00:00:01
# Total run time:  10.12s
# 10.0%. Run time:   1.04s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.05s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.04s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.06s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.07s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.13s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.14s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.18s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.21s. Est. time left: 00:00:00:01
# Total run time:  10.23s
# 10.0%. Run time:   1.00s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.02s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.04s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.05s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.09s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.12s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.15s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.15s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.16s. Est. time left: 00:00:00:01
# Total run time:  10.18s
# 10.0%. Run time:   1.01s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.00s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.03s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.04s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.05s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.06s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.10s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.11s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.14s. Est. time left: 00:00:00:01
# Total run time:  10.11s
# 10.0%. Run time:   1.02s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.01s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.00s. Est. time left: 00:00:00:06
# 40.0%. Run time:   4.00s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.04s. Est. time left: 00:00:00:05
# 60.0%. Run time:   5.97s. Est. time left: 00:00:00:03
# 70.0%. Run time:   7.00s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.00s. Est. time left: 00:00:00:01
# 90.0%. Run time:   9.00s. Est. time left: 00:00:00:00
# Total run time:   9.93s
# 10.0%. Run time:   1.02s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.01s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.02s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.02s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.05s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.00s. Est. time left: 00:00:00:03
# 70.0%. Run time:   7.02s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.03s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.03s. Est. time left: 00:00:00:01
# Total run time:  10.03s
# 10.0%. Run time:   1.02s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.01s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.02s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.03s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.05s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.03s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.06s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.06s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.05s. Est. time left: 00:00:00:01
# Total run time:  10.08s
# 10.0%. Run time:   1.05s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.07s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.14s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.18s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.23s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.28s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.33s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.40s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.43s. Est. time left: 00:00:00:01
# Total run time:  10.44s
# 10.0%. Run time:   1.08s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.21s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.25s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.29s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.37s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.46s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.49s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.55s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.62s. Est. time left: 00:00:00:01
# Total run time:  10.65s
# 10.0%. Run time:   1.05s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.20s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.24s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.27s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.39s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.44s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.48s. Est. time left: 00:00:00:03
# 80.0%. Run time:   8.60s. Est. time left: 00:00:00:02
# 90.0%. Run time:   9.66s. Est. time left: 00:00:00:01
# Total run time:  10.68s

# %%
fig, ax = plt.subplots(figsize=(21,9))
spacing = 3
for i, result in enumerate(results):
    if i%spacing==0:
        probs = np.abs(result.states) ** 2
        ax.plot(result.times, probs[:,1,0], label=f"{round(δvs[i],4)*1000:0.1f}MHz")
ax.set_xlabel("Time [ns]")
ax.set_ylabel("Probability")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Two-Field Simulation with Master Equation

# %%
δν = 0.025
νp = 5.0
Ωx = 0.0633
ϵ = 5.0
Sx = σx()/2
Sy = σy()/2
Sz = σz()/2
ψ0 = basis(2, 0)
times = np.linspace(0, 250, 2500)
result = sesolve(H2, ψ0, times, e_ops=[], args=dict(eps=ϵ, vp=νp, omegaX=Ωx, dv=δν), progress_bar=True)
